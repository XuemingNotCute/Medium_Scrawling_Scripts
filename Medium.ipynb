# %%
import pandas as pd
import numpy as np
import urllib
import urllib.request
from bs4 import BeautifulSoup

# %%
def unique(it):
        s = set()
        for el in it:
            if el not in s:
                s.add(el)
                yield el

# %%
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

browser = webdriver.Chrome("/Users/admin/Desktop/xxm/chromedriver")

browser.get("https://medium.com/topic/popular")
time.sleep(1)

elem = browser.find_element_by_tag_name("body")

no_of_pagedowns = 2500

while no_of_pagedowns:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.1)
    no_of_pagedowns-=1
    
    
#page = requests.get("https://medium.com/topic/culture")
#soup = BeautifulSoup(page.content, 'html.parser')

#post_elems = browser.find_elements_by_class_name("a")


#for post in post_elems:
    #print(post.text)
    
#print("------------------")

#print(browser)


print("printed all links")

time.sleep(1)
data = browser.page_source
soup = BeautifulSoup(data, "html.parser")
# Out:
# printed all links

# %%
time.sleep(2)
data = browser.page_source
soup = BeautifulSoup(data, "html.parser")

# %%
text=[]
i=0
for link in soup.find_all("h3", {"class": "bu bv bw w bx x ck ea eb d ct ec ed"}):
    #print(i)
    text.append(link.text.replace('\n', ''))
    i=i+1

# %%
links_with_text = []
for a in soup.find_all('a', href=True): 
    if a.text: 
        links_with_text.append(a['href'])
res = [k for k in links_with_text if 'source=topic_page' in k]
res1 = [k for k in res if '/p' in k]
res2=list(unique(res1))

# %%
res2
# Out:
# ['/p/a3832f587bee?source=topic_page---------0------------------20',
#  '/p/af4499558ce0?source=topic_page---------1------------------20',
#  '/p/b64c40484774?source=topic_page---------2------------------20',
#  '/p/36fbed0268cf?source=topic_page---------3------------------20',
#  '/p/22c43f236ff5?source=topic_page---------4------------------20',
#  '/p/7a3088cdff78?source=topic_page---------5------------------20',
#  '/p/17db67de2532?source=topic_page---------6------------------20',
#  '/p/9b96528db259?source=topic_page---------7------------------20',
#  '/p/54add1467545?source=topic_page---------8------------------20',
#  '/p/ec30ac17172d?source=topic_page---------9------------------20',
#  '/p/a3832f587bee?source=topic_page---------0------------------1',
#  '/p/af4499558ce0?source=topic_page---------1------------------1',
#  '/p/b64c40484774?source=topic_page---------2------------------1',
#  '/p/36fbed0268cf?source=topic_page---------4------------------1',
#  '/p/22c43f236ff5?source=topic_page---------5------------------1',
#  '/p/7a3088cdff78?source=topic_page---------6------------------1',
#  '/p/3b6b1885b5a1?source=topic_page---------7------------------1',
#  '/p/17db67de2532?source=topic_page---------8------------------1',
#  '/p/9b96528db259?source=topic_page---------9------------------1',
#  '/p/ddf9780d714c?source=topic_page---------10------------------1',
#  '/p/727c8ece07b7?source=topic_page---------11------------------1',
#  '/p/2d53766507d2?source=topic_page---------12------------------1',
#  '/p/54add1467545?source=topic_page---------13------------------1',
#  '/p/9673546b19af?source=topic_page---------14------------------1',
#  '/p/ec30ac17172d?source=topic_page---------15------------------1',
#  '/p/31f7964a96d8?source=topic_page---------16------------------1',
#  '/p/fa01c1f75d3f?source=topic_page---------17------------------1',
#  '/p/87f92217d085?source=topic_page---------18------------------1',
#  '/p/264d483ee0de?source=topic_page---------19------------------1',
#  '/p/a8659060cab5?source=topic_page---------20------------------1',
#  '/p/5b47631d7f4c?source=topic_page---------21------------------1',
#  '/p/f34e199b199b?source=topic_page---------22------------------1',
#  '/p/777ffea6fabf?source=topic_page---------23------------------1',
#  '/p/9d54fe7500eb?source=topic_page---------24------------------1',
#  '/p/9744c8e7322f?source=topic_page---------25------------------1',
#  '/p/4ed4fe9a454f?source=topic_page---------26------------------1',
#  '/p/920436c1e25?source=topic_page---------27------------------1',
#  '/p/eded62c5eda9?source=topic_page---------28------------------1',
#  '/p/1deee3053bf6?source=topic_page---------29------------------1',
#  '/p/49046af171ac?source=topic_page---------30------------------1',
#  '/p/2613711712de?source=topic_page---------31------------------1',
#  '/p/a3065cc41f06?source=topic_page---------32------------------1',
#  '/p/f80d9d373362?source=topic_page---------33------------------1',
#  '/p/4a61c54114fa?source=topic_page---------34------------------1',
#  '/p/169a42b92a77?source=topic_page---------35------------------1',
#  '/p/79b86aabeec3?source=topic_page---------36------------------1',
#  '/p/e8875a1c6067?source=topic_page---------37------------------1',
#  '/p/f24e19ef514f?source=topic_page---------38------------------1',
#  '/p/4ebed5646f98?source=topic_page---------39------------------1',
#  '/p/62fb4caa2b21?source=topic_page---------40------------------1',
#  '/p/914e64e0eabc?source=topic_page---------41------------------1',
#  '/p/ffd0792b6a23?source=topic_page---------42------------------1',
#  '/p/cb11c4acffb1?source=topic_page---------43------------------1',
#  '/p/a11bd134da13?source=topic_page---------44------------------1',
#  '/p/89d03fc149c6?source=topic_page---------45------------------1',
#  '/p/a393e8512548?source=topic_page---------46------------------1',
#  '/p/3d5083a0da5a?source=topic_page---------47------------------1',
#  '/p/7ba19eecab4d?source=topic_page---------48------------------1',
#  '/p/50eea39ef43?source=topic_page---------49------------------1',
#  '/p/cf4f2f8c6dd4?source=topic_page---------50------------------1',
#  '/p/7c19ab69db1e?source=topic_page---------51------------------1',
#  '/p/bedd1b2447d?source=topic_page---------52------------------1',
#  '/p/eb0e8288a7e5?source=topic_page---------53------------------1',
#  '/p/948d93f7a396?source=topic_page---------54------------------1',
#  '/p/b4b1ac61f5b0?source=topic_page---------55------------------1',
#  '/p/50d47ba7be8f?source=topic_page---------56------------------1',
#  '/p/1161d7b12256?source=topic_page---------57------------------1',
#  '/p/5552c981d612?source=topic_page---------58------------------1',
#  '/p/b89f63d21558?source=topic_page---------59------------------1',
#  '/p/d8d433a0f0bf?source=topic_page---------60------------------1',
#  '/p/1e5658f41a5?source=topic_page---------61------------------1',
#  '/p/9fd506428204?source=topic_page---------62------------------1',
#  '/p/5bedcac067ee?source=topic_page---------63------------------1',
#  '/p/4f1e0bc05cfe?source=topic_page---------64------------------1',
#  '/p/9470cfafaabd?source=topic_page---------65------------------1',
#  '/p/5946935d93fe?source=topic_page---------66------------------1',
#  '/p/4d683e3a0e47?source=topic_page---------67------------------1',
#  '/p/756e3de7c6b6?source=topic_page---------68------------------1',
#  '/p/b70f87b0b2a6?source=topic_page---------69------------------1',
#  '/p/80d649792c36?source=topic_page---------70------------------1',
#  '/p/c5c52d620176?source=topic_page---------71------------------1',
#  '/p/b6b31cfc4099?source=topic_page---------72------------------1',
#  '/p/1c3256d12f1d?source=topic_page---------73------------------1',
#  '/p/5a9a5730cafa?source=topic_page---------74------------------1',
#  '/p/317e1db7a919?source=topic_page---------75------------------1',
#  '/p/6ef443c2a094?source=topic_page---------76------------------1',
#  '/p/b364e0ba545c?source=topic_page---------77------------------1',
#  '/p/18b04646a0d7?source=topic_page---------78------------------1',
#  '/p/948e7f074f55?source=topic_page---------79------------------1',
#  '/p/240933534fc0?source=topic_page---------80------------------1',
#  '/p/aea41eabe66e?source=topic_page---------81------------------1',
#  '/p/b2496e9d679d?source=topic_page---------82------------------1',
#  '/p/e0a8c12e863d?source=topic_page---------83------------------1',
#  '/p/46ccbd9780c3?source=topic_page---------84------------------1',
#  '/p/59933d12a3cc?source=topic_page---------85------------------1',
#  '/p/6b4a91336a73?source=topic_page---------86------------------1',
#  '/p/4b0e6021570e?source=topic_page---------87------------------1',
#  '/p/d2580999b8c4?source=topic_page---------88------------------1',
#  '/p/4c7c0af6c56?source=topic_page---------89------------------1',
#  '/p/2b1999f2d942?source=topic_page---------90------------------1',
#  '/p/30b5fb617a?source=topic_page---------91------------------1',
#  '/p/6b8f5e702533?source=topic_page---------92------------------1',
#  '/p/857cfe8c8c96?source=topic_page---------93------------------1',
#  '/p/c890f16f4e4d?source=topic_page---------94------------------1',
#  '/p/66426e74cec5?source=topic_page---------95------------------1',
#  '/p/31433bfc210a?source=topic_page---------96------------------1',
#  '/p/26339f572e7f?source=topic_page---------97------------------1',
#  '/p/f6af7b8161a2?source=topic_page---------98------------------1',
#  '/p/1863dad5944d?source=topic_page---------99------------------1',
#  '/p/63f6d84bec7a?source=topic_page---------100------------------1',
#  '/p/56854fca9109?source=topic_page---------101------------------1',
#  '/p/157be2a24e98?source=topic_page---------102------------------1',
#  '/p/f2a2c1bf74bf?source=topic_page---------103------------------1',
#  '/p/8e203a6ad291?source=topic_page---------104------------------1',
#  '/p/1b72a3fb4bcf?source=topic_page---------105------------------1',
#  '/p/ed8b2fcd1e90?source=topic_page---------106------------------1',
#  '/p/6912378afc6e?source=topic_page---------107------------------1',
#  '/p/eb07cba689b8?source=topic_page---------108------------------1',
#  '/p/9de52f485a76?source=topic_page---------109------------------1',
#  '/p/b24ac8c3c23a?source=topic_page---------110------------------1',
#  '/p/32321a4b6601?source=topic_page---------111------------------1',
#  '/p/f2e9ac4c4848?source=topic_page---------112------------------1',
#  '/p/17065434385b?source=topic_page---------113------------------1',
#  '/p/5ddc810057f2?source=topic_page---------114------------------1',
#  '/p/39626c002f77?source=topic_page---------115------------------1',
#  '/p/8c002acec19?source=topic_page---------116------------------1',
#  '/p/ce01c3187429?source=topic_page---------117------------------1',
#  '/p/625c05b29692?source=topic_page---------118------------------1',
#  '/p/6c92e355612b?source=topic_page---------119------------------1',
#  '/p/295e55500990?source=topic_page---------120------------------1',
#  '/p/39b1aa289878?source=topic_page---------121------------------1',
#  '/p/68cafd6cda98?source=topic_page---------122------------------1',
#  '/p/be13fbe352d2?source=topic_page---------123------------------1',
#  '/p/10bd98614fa9?source=topic_page---------124------------------1',
#  '/p/b9d9104e2d34?source=topic_page---------125------------------1',
#  '/p/4eb38a2e5610?source=topic_page---------126------------------1',
#  '/p/368780082573?source=topic_page---------127------------------1',
#  '/p/6a08b22b9689?source=topic_page---------128------------------1',
#  '/p/b04741f39b1b?source=topic_page---------129------------------1',
#  '/p/fc58fa7a7c15?source=topic_page---------130------------------1',
#  '/p/5874731c42ed?source=topic_page---------131------------------1',
#  '/p/3e124aff36f8?source=topic_page---------132------------------1',
#  '/p/8f918529009a?source=topic_page---------133------------------1',
#  '/p/3b1adb8980ed?source=topic_page---------134------------------1',
#  '/p/789b954f06ae?source=topic_page---------135------------------1',
#  '/p/809e368c0fdb?source=topic_page---------136------------------1',
#  '/p/eb739452db0e?source=topic_page---------137------------------1',
#  '/p/a2d417ef9157?source=topic_page---------138------------------1',
#  '/p/db0a14267c2e?source=topic_page---------139------------------1',
#  '/p/71e0517294a0?source=topic_page---------140------------------1',
#  '/p/492213744af8?source=topic_page---------141------------------1',
#  '/p/43af017e2683?source=topic_page---------142------------------1',
#  '/p/8cef6b06b4f4?source=topic_page---------143------------------1',
#  '/p/83bf4977b0ac?source=topic_page---------144------------------1',
#  '/p/30b4841b2895?source=topic_page---------145------------------1',
#  '/p/bfebe857a457?source=topic_page---------146------------------1',
#  '/p/1981a2af1fda?source=topic_page---------147------------------1',
#  '/p/7a288b0ef914?source=topic_page---------148------------------1',
#  '/p/291efac43037?source=topic_page---------149------------------1',
#  '/p/c26fe90d5303?source=topic_page---------150------------------1',
#  '/p/fd9e37b6d520?source=topic_page---------151------------------1',
#  '/p/e50af6971daf?source=topic_page---------152------------------1',
#  '/p/198b519ca397?source=topic_page---------153------------------1',
#  '/p/d7d3b6d3f1e7?source=topic_page---------154------------------1',
#  '/p/6d0802a47c05?source=topic_page---------155------------------1',
#  '/p/5f6a9da9345c?source=topic_page---------156------------------1',
#  '/p/9ade983d95e6?source=topic_page---------157------------------1',
#  '/p/aadb4bc0266c?source=topic_page---------158------------------1',
#  '/p/15b3071613e6?source=topic_page---------159------------------1',
#  '/p/60b77022117b?source=topic_page---------160------------------1',
#  '/p/86a816e2bf07?source=topic_page---------161------------------1',
#  '/p/d18a74a2ebe9?source=topic_page---------162------------------1',
#  '/p/7c5ffd0ba4c5?source=topic_page---------163------------------1',
#  '/p/8491b446dde5?source=topic_page---------164------------------1',
#  '/p/e817875d1c5c?source=topic_page---------165------------------1',
#  '/p/e69f9086bc9c?source=topic_page---------166------------------1',
#  '/p/fb4d16a4505?source=topic_page---------167------------------1',
#  '/p/7e1f214c0c07?source=topic_page---------168------------------1',
#  '/p/51b4a7354e06?source=topic_page---------169------------------1',
#  '/p/dc2b3a3b541c?source=topic_page---------170------------------1',
#  '/p/98c8cd01d2ae?source=topic_page---------171------------------1',
#  '/p/35c55c1b6fed?source=topic_page---------172------------------1',
#  '/p/309187757d4e?source=topic_page---------173------------------1',
#  '/p/57dac53ce28c?source=topic_page---------174------------------1',
#  '/p/b4ab8ab81919?source=topic_page---------175------------------1',
#  '/p/ad49d3f081cc?source=topic_page---------176------------------1',
#  '/p/1f9760765b46?source=topic_page---------177------------------1',
#  '/p/ec65b5193385?source=topic_page---------178------------------1',
#  '/p/54320a236369?source=topic_page---------179------------------1',
#  '/p/ba425aa86fcb?source=topic_page---------180------------------1',
#  '/p/b97794a0e330?source=topic_page---------181------------------1',
#  '/p/f13c14e007b9?source=topic_page---------182------------------1',
#  '/p/69d2cea88343?source=topic_page---------183------------------1',
#  '/p/ea97cb984ef0?source=topic_page---------184------------------1',
#  '/p/c1525a15e9aa?source=topic_page---------185------------------1',
#  '/p/6d9a0888df01?source=topic_page---------186------------------1',
#  '/p/c124d4daf212?source=topic_page---------187------------------1',
#  '/p/b467524ee747?source=topic_page---------188------------------1',
#  '/p/f7b5fb9a7af5?source=topic_page---------189------------------1',
#  '/p/5d84a6c751e1?source=topic_page---------190------------------1',
#  '/p/e5dc06e72549?source=topic_page---------191------------------1',
#  '/p/5621c96af027?source=topic_page---------192------------------1',
#  '/p/f08c20e02ffe?source=topic_page---------193------------------1',
#  '/p/81d0127bd738?source=topic_page---------194------------------1',
#  '/p/1767cb03af20?source=topic_page---------195------------------1',
#  '/p/bbc904edd46a?source=topic_page---------196------------------1',
#  '/p/6c552a1cfc25?source=topic_page---------197------------------1',
#  '/p/7cfc423efb44?source=topic_page---------198------------------1',
#  '/p/6727936d3ffc?source=topic_page---------199------------------1',
#  '/p/bd10bbabaf35?source=topic_page---------200------------------1',
#  '/p/245d058cf4de?source=topic_page---------201------------------1',
#  '/p/e94fc313a3d6?source=topic_page---------202------------------1',
#  '/p/dee78b3070e6?source=topic_page---------203------------------1',
#  '/p/7763f90d5abb?source=topic_page---------204------------------1',
#  '/p/f052555fbfe7?source=topic_page---------205------------------1',
#  '/p/51dd0a9e4511?source=topic_page---------206------------------1',
#  '/p/727551e16a72?source=topic_page---------207------------------1',
#  '/p/feb3ba8dbfc0?source=topic_page---------208------------------1',
#  '/p/a1239d7a11d5?source=topic_page---------209------------------1',
#  '/p/d137a36201a7?source=topic_page---------210------------------1',
#  '/p/9916930f920a?source=topic_page---------211------------------1',
#  '/p/ae6a14991059?source=topic_page---------212------------------1',
#  '/p/7d0d34d98971?source=topic_page---------213------------------1',
#  '/p/69bd85ef12c8?source=topic_page---------214------------------1',
#  '/p/c0c081b8c970?source=topic_page---------215------------------1',
#  '/p/4dd1bde1a772?source=topic_page---------216------------------1',
#  '/p/129844f1c5ab?source=topic_page---------217------------------1',
#  '/p/7d67242675e2?source=topic_page---------218------------------1',
#  '/p/24070e96d906?source=topic_page---------219------------------1',
#  '/p/8989790678e9?source=topic_page---------220------------------1',
#  '/p/221e678c642b?source=topic_page---------221------------------1',
#  '/p/d87199a18bed?source=topic_page---------222------------------1',
#  '/p/eacf251d78ad?source=topic_page---------223------------------1',
#  '/p/90d5e367c2c5?source=topic_page---------224------------------1',
#  '/p/3984a01952cf?source=topic_page---------225------------------1',
#  '/p/8020c88fd5f?source=topic_page---------226------------------1',
#  '/p/6e4fed3fd1d4?source=topic_page---------227------------------1',
#  '/p/ea53719c34a5?source=topic_page---------228------------------1',
#  '/p/9d79a33e7eb3?source=topic_page---------229------------------1',
#  '/p/e3d9eaebd7e9?source=topic_page---------230------------------1',
#  '/p/2ff455fb52d4?source=topic_page---------231------------------1',
#  '/p/efd7646b958a?source=topic_page---------232------------------1',
#  '/p/621c42238479?source=topic_page---------233------------------1',
#  '/p/19e800ce0d21?source=topic_page---------234------------------1',
#  '/p/c0878418343f?source=topic_page---------235------------------1',
#  '/p/6e962acd4804?source=topic_page---------236------------------1',
#  '/p/8cc9023399e4?source=topic_page---------237------------------1',
#  '/p/ac9987bda1dd?source=topic_page---------238------------------1',
#  '/p/856ce2e73876?source=topic_page---------239------------------1',
#  '/p/f0312a5eafb2?source=topic_page---------240------------------1',
#  '/p/73b6a0efd0ee?source=topic_page---------241------------------1',
#  '/p/f4530bf5761f?source=topic_page---------242------------------1',
#  '/p/27e09dfeb246?source=topic_page---------243------------------1',
#  '/p/e278e11a16e0?source=topic_page---------244------------------1',
#  '/p/e1045057468f?source=topic_page---------245------------------1',
#  '/p/def231fb63e2?source=topic_page---------246------------------1',
#  '/p/3ca829f389f4?source=topic_page---------247------------------1',
#  '/p/549dfcfc1d53?source=topic_page---------248------------------1',
#  '/p/3ba86977eced?source=topic_page---------249------------------1',
#  '/p/678c51b4b463?source=topic_page---------250------------------1',
#  '/p/b853b8621ac7?source=topic_page---------251------------------1',
#  '/p/f90beaf4dd41?source=topic_page---------252------------------1',
#  '/p/5141b7fbfe06?source=topic_page---------253------------------1',
#  '/p/591ee3221233?source=topic_page---------254------------------1',
#  '/p/d01e089b4e34?source=topic_page---------255------------------1',
#  '/p/7588781774b3?source=topic_page---------256------------------1',
#  '/p/72ceeb078373?source=topic_page---------257------------------1',
#  '/p/dbbe9d250b2e?source=topic_page---------258------------------1',
#  '/p/ef03260747f3?source=topic_page---------259------------------1',
#  '/p/ddea7b598df7?source=topic_page---------260------------------1',
#  '/p/491f24b233c8?source=topic_page---------261------------------1',
#  '/p/8985870471a5?source=topic_page---------262------------------1',
#  '/p/286b2936ae96?source=topic_page---------263------------------1',
#  '/p/15b434aeb2b6?source=topic_page---------264------------------1',
#  '/p/d347e4dd3f6e?source=topic_page---------265------------------1',
#  '/p/24e837246fb8?source=topic_page---------266------------------1',
#  '/p/d086518a4522?source=topic_page---------267------------------1',
#  '/p/5d0ae19356f3?source=topic_page---------268------------------1',
#  '/p/1f64ce28c38d?source=topic_page---------269------------------1',
#  '/p/7e8b88d32fde?source=topic_page---------270------------------1',
#  '/p/b09aa2c4d727?source=topic_page---------271------------------1',
#  '/p/f3f7dda84bae?source=topic_page---------272------------------1',
#  '/p/2cb43946551a?source=topic_page---------273------------------1',
#  '/p/253c800e9428?source=topic_page---------274------------------1',
#  '/p/c3bfe30f2d74?source=topic_page---------275------------------1',
#  '/p/7a376ea7bd4b?source=topic_page---------276------------------1',
#  '/p/4dbe16cbf20a?source=topic_page---------277------------------1',
#  '/p/1a18a1cb380a?source=topic_page---------278------------------1',
#  '/p/4476ccbf53a8?source=topic_page---------279------------------1',
#  '/p/5f88ab9cda05?source=topic_page---------280------------------1',
#  '/p/917dc88a84db?source=topic_page---------281------------------1',
#  '/p/59614efccbaf?source=topic_page---------282------------------1',
#  '/p/bf52302390f8?source=topic_page---------283------------------1',
#  '/p/1415a89330e3?source=topic_page---------284------------------1',
#  '/p/489cef9859e5?source=topic_page---------285------------------1',
#  '/p/53fe7e06359e?source=topic_page---------286------------------1',
#  '/p/85491d944de3?source=topic_page---------287------------------1',
#  '/p/7140bd0c30e3?source=topic_page---------288------------------1',
#  '/p/463526af852f?source=topic_page---------289------------------1',
#  '/p/7a5be5bc3d9a?source=topic_page---------290------------------1',
#  '/p/ec30e0c1314e?source=topic_page---------291------------------1',
#  '/p/48a99b85aad4?source=topic_page---------292------------------1',
#  '/p/5f7f49a96ec8?source=topic_page---------293------------------1',
#  '/p/3a50ac8c877c?source=topic_page---------294------------------1',
#  '/p/80ec3a06667b?source=topic_page---------295------------------1',
#  '/p/3748f296dfb7?source=topic_page---------296------------------1',
#  '/p/795a61f5e5dc?source=topic_page---------297------------------1',
#  '/p/13b9c95c75bd?source=topic_page---------298------------------1',
#  '/p/e9cc6b59c49d?source=topic_page---------299------------------1',
#  '/p/be360c7911b4?source=topic_page---------300------------------1',
#  '/p/5a57a9b1be86?source=topic_page---------301------------------1',
#  '/p/ffde5fe8d11?source=topic_page---------302------------------1',
#  '/p/f93a5aa38c97?source=topic_page---------303------------------1',
#  '/p/9d7b82ebb060?source=topic_page---------304------------------1',
#  '/p/968268c53ffd?source=topic_page---------305------------------1',
#  '/p/877c346debf4?source=topic_page---------306------------------1',
#  '/p/107645552063?source=topic_page---------307------------------1',
#  '/p/b06f160838da?source=topic_page---------308------------------1',
#  '/p/5d5d9ed94503?source=topic_page---------309------------------1',
#  '/p/c9e7b64519bb?source=topic_page---------310------------------1',
#  '/p/68a3d9e5a920?source=topic_page---------311------------------1',
#  '/p/2899382f0f90?source=topic_page---------312------------------1',
#  '/p/a7d8f5a850a3?source=topic_page---------313------------------1',
#  '/p/c4ce548d17e1?source=topic_page---------314------------------1',
#  '/p/2d2f8e27d0e4?source=topic_page---------315------------------1',
#  '/p/7b4521cb6379?source=topic_page---------316------------------1',
#  '/p/217db9889c07?source=topic_page---------317------------------1',
#  '/p/8b4740dc453c?source=topic_page---------318------------------1',
#  '/p/ae438985fcca?source=topic_page---------319------------------1',
#  '/p/66115d156c81?source=topic_page---------320------------------1',
#  '/p/d0b62f5dd1bf?source=topic_page---------321------------------1',
#  '/p/c1e6ae9445bd?source=topic_page---------322------------------1',
#  '/p/ae4fc490613b?source=topic_page---------323------------------1',
#  '/p/70ab2a61f9ff?source=topic_page---------324------------------1',
#  '/p/577e2b96b19f?source=topic_page---------325------------------1',
#  '/p/644d1ec2f812?source=topic_page---------326------------------1',
#  '/p/139884a006b4?source=topic_page---------327------------------1',
#  '/p/66d94e2152c7?source=topic_page---------328------------------1',
#  '/p/97e6a7a385f7?source=topic_page---------329------------------1',
#  '/p/7f1fdfdb6081?source=topic_page---------330------------------1',
#  '/p/ac3512d4d704?source=topic_page---------331------------------1',
#  '/p/7555f9f7543?source=topic_page---------332------------------1',
#  '/p/52a7c5171d8f?source=topic_page---------333------------------1',
#  '/p/36af0831f5e3?source=topic_page---------334------------------1',
#  '/p/376a3f95ad60?source=topic_page---------335------------------1',
#  '/p/34116f1ca5f2?source=topic_page---------336------------------1',
#  '/p/7d8950fbb5d4?source=topic_page---------337------------------1',
#  '/p/8cfcb55e3d7?source=topic_page---------338------------------1',
#  '/p/7e9c9dcf8ba7?source=topic_page---------339------------------1',
#  '/p/4b59adab4a2e?source=topic_page---------340------------------1',
#  '/p/27d5307b7606?source=topic_page---------341------------------1',
#  '/p/9d8c4e01a026?source=topic_page---------342------------------1',
#  '/p/2766d311bfae?source=topic_page---------343------------------1',
#  '/p/7b447c143d52?source=topic_page---------344------------------1',
#  '/p/d3eb6bb1e7d0?source=topic_page---------345------------------1',
#  '/p/e4c360ce3a27?source=topic_page---------346------------------1',
#  '/p/be08be6ed482?source=topic_page---------347------------------1',
#  '/p/bab96fe01c9a?source=topic_page---------348------------------1',
#  '/p/c47defb033d2?source=topic_page---------349------------------1',
#  '/p/448b916138b8?source=topic_page---------350------------------1',
#  '/p/c0fd1a917181?source=topic_page---------351------------------1',
#  '/p/b0ceb1407c61?source=topic_page---------352------------------1',
#  '/p/5498c0eb428b?source=topic_page---------353------------------1',
#  '/p/9b73c84212d0?source=topic_page---------354------------------1',
#  '/p/4545b48742b1?source=topic_page---------355------------------1',
#  '/p/e9a1ae8077fd?source=topic_page---------356------------------1',
#  '/p/401b11160ecc?source=topic_page---------357------------------1',
#  '/p/8543519677d4?source=topic_page---------358------------------1',
#  '/p/82e275c8764f?source=topic_page---------359------------------1',
#  '/p/d846d2786b84?source=topic_page---------360------------------1',
#  '/p/f178818a728b?source=topic_page---------361------------------1',
#  '/p/59f857d1868a?source=topic_page---------362------------------1',
#  '/p/e57a6bc542cf?source=topic_page---------363------------------1',
#  '/p/6801864f8f97?source=topic_page---------364------------------1',
#  '/p/a45c0209135f?source=topic_page---------365------------------1',
#  '/p/5e1d6de787b7?source=topic_page---------366------------------1',
#  '/p/9e6365b6c516?source=topic_page---------367------------------1',
#  '/p/86de9a8efb24?source=topic_page---------368------------------1',
#  '/p/a4277737152e?source=topic_page---------369------------------1',
#  '/p/b44c17b9e3d6?source=topic_page---------370------------------1',
#  '/p/38ea0c17b7db?source=topic_page---------371------------------1',
#  '/p/248676be71c1?source=topic_page---------372------------------1',
#  '/p/26d406b853a2?source=topic_page---------373------------------1',
#  '/p/933091235095?source=topic_page---------374------------------1',
#  '/p/f87ef12a9caa?source=topic_page---------375------------------1',
#  '/p/e0cfd1ad11a8?source=topic_page---------376------------------1',
#  '/p/d2f72cd69b9c?source=topic_page---------377------------------1',
#  '/p/65064d0cdd59?source=topic_page---------378------------------1',
#  '/p/3b4fc87dc6b5?source=topic_page---------379------------------1',
#  '/p/8013ff47d46e?source=topic_page---------380------------------1',
#  '/p/ae924e44581a?source=topic_page---------381------------------1',
#  '/p/47c958ad1b72?source=topic_page---------382------------------1',
#  '/p/4c740cf0c5a5?source=topic_page---------383------------------1',
#  '/p/20dcad2a6735?source=topic_page---------384------------------1',
#  '/p/430b973febd?source=topic_page---------385------------------1',
#  '/p/c3b507fa7f12?source=topic_page---------386------------------1',
#  '/p/db4f9116be08?source=topic_page---------387------------------1',
#  '/p/70f681cd255a?source=topic_page---------388------------------1',
#  '/p/a13c0412e50d?source=topic_page---------389------------------1',
#  '/p/d4f2921bd1b8?source=topic_page---------390------------------1',
#  '/p/5dba250bf9c3?source=topic_page---------391------------------1',
#  '/p/8514a0007939?source=topic_page---------392------------------1',
#  '/p/f4a2f4129e05?source=topic_page---------393------------------1',
#  '/p/4b29c8ed996e?source=topic_page---------394------------------1',
#  '/p/6bfb660a2a2?source=topic_page---------395------------------1',
#  '/p/96c40abe3467?source=topic_page---------396------------------1',
#  '/p/4e8e6b8e929d?source=topic_page---------397------------------1',
#  '/p/73c0895d0ff1?source=topic_page---------398------------------1',
#  '/p/14176e177ca3?source=topic_page---------399------------------1',
#  '/p/5c8c51d7ed14?source=topic_page---------400------------------1',
#  '/p/39cb10beabeb?source=topic_page---------401------------------1',
#  '/p/4ae78d9ac75f?source=topic_page---------402------------------1',
#  '/p/be2e064a45f4?source=topic_page---------403------------------1',
#  '/p/aee7d99252af?source=topic_page---------404------------------1',
#  '/p/efcff645141c?source=topic_page---------405------------------1',
#  '/p/c56838f49738?source=topic_page---------406------------------1',
#  '/p/2e1701d2de1f?source=topic_page---------407------------------1',
#  '/p/c4486c1ee9c4?source=topic_page---------408------------------1',
#  '/p/bf20324ba420?source=topic_page---------409------------------1',
#  '/p/c5ba718acfc9?source=topic_page---------410------------------1',
#  '/p/513a46d96000?source=topic_page---------411------------------1',
#  '/p/3a2b20c12c97?source=topic_page---------412------------------1',
#  '/p/90eb10e38b1c?source=topic_page---------413------------------1',
#  '/p/e289036ee01c?source=topic_page---------414------------------1',
#  '/p/12f567f13a91?source=topic_page---------415------------------1',
#  '/p/d43925d8a40c?source=topic_page---------416------------------1',
#  '/p/2bebafb22203?source=topic_page---------417------------------1',
#  '/p/de8d9442d0d?source=topic_page---------418------------------1',
#  '/p/d62cfe286eb8?source=topic_page---------419------------------1',
#  '/p/83991bc994c4?source=topic_page---------420------------------1',
#  '/p/d42756f46dba?source=topic_page---------421------------------1',
#  '/p/fd090ad4469b?source=topic_page---------422------------------1',
#  '/p/a1732c32a72f?source=topic_page---------423------------------1',
#  '/p/7af99c1d9c4f?source=topic_page---------424------------------1',
#  '/p/6a0192346506?source=topic_page---------425------------------1',
#  '/p/ccbdf31e2f4e?source=topic_page---------426------------------1',
#  '/p/3f4b7f5d3b33?source=topic_page---------427------------------1',
#  '/p/6803a8c290cf?source=topic_page---------428------------------1',
#  '/p/87e378237792?source=topic_page---------429------------------1',
#  '/p/83f9c8fe631c?source=topic_page---------430------------------1',
#  '/p/eae6f124cacd?source=topic_page---------431------------------1',
#  '/p/e5074b6fe55b?source=topic_page---------432------------------1',
#  '/p/b6500139a009?source=topic_page---------433------------------1',
#  '/p/66fcf019569c?source=topic_page---------434------------------1',
#  '/p/4fcfc2428d88?source=topic_page---------435------------------1',
#  '/p/afa677763973?source=topic_page---------436------------------1',
#  '/p/3e07c7a561c9?source=topic_page---------437------------------1',
#  '/p/41b97067730?source=topic_page---------438------------------1',
#  '/p/969afea0d08f?source=topic_page---------439------------------1',
#  '/p/9e0f913ab7a6?source=topic_page---------440------------------1',
#  '/p/71bbbcb7310b?source=topic_page---------441------------------1',
#  '/p/b374f42bc318?source=topic_page---------442------------------1',
#  '/p/2294c3f36311?source=topic_page---------443------------------1',
#  '/p/56939a087080?source=topic_page---------444------------------1',
#  '/p/84d148b6f3eb?source=topic_page---------445------------------1',
#  '/p/4e0d7404043a?source=topic_page---------446------------------1',
#  '/p/615434c6eeba?source=topic_page---------447------------------1',
#  '/p/e655c04cebb8?source=topic_page---------448------------------1',
#  '/p/8f5c15d4b527?source=topic_page---------449------------------1',
#  '/p/a3224e126947?source=topic_page---------450------------------1',
#  '/p/e84a2004ee39?source=topic_page---------451------------------1',
#  '/p/42bd9cd294e3?source=topic_page---------452------------------1',
#  '/p/d4543e09f9ff?source=topic_page---------453------------------1',
#  '/p/ddc60d7139f1?source=topic_page---------454------------------1',
#  '/p/45b714dfbed1?source=topic_page---------455------------------1',
#  '/p/d481390bfcee?source=topic_page---------456------------------1',
#  '/p/3c8b8c0d21ba?source=topic_page---------457------------------1',
#  '/p/6d8688a4b0a3?source=topic_page---------458------------------1',
#  '/p/918ca0962566?source=topic_page---------459------------------1',
#  '/p/275a33bb6e9c?source=topic_page---------460------------------1',
#  '/p/4c2f3f85793a?source=topic_page---------461------------------1',
#  '/p/dac6d65e9015?source=topic_page---------462------------------1',
#  '/p/1c84daf9fd62?source=topic_page---------463------------------1',
#  '/p/1b79905adf45?source=topic_page---------464------------------1',
#  '/p/5f566517c79c?source=topic_page---------465------------------1',
#  '/p/a1482e889fcb?source=topic_page---------466------------------1',
#  '/p/f7d475ec0177?source=topic_page---------467------------------1',
#  '/p/b644651b383a?source=topic_page---------468------------------1',
#  '/p/f4e964087b16?source=topic_page---------469------------------1',
#  '/p/3775a5cdfe1d?source=topic_page---------470------------------1',
#  '/p/dcab49155643?source=topic_page---------471------------------1',
#  '/p/3d5545db7665?source=topic_page---------472------------------1',
#  '/p/977f3b6c73b3?source=topic_page---------473------------------1',
#  '/p/c6e36763574b?source=topic_page---------474------------------1',
#  '/p/f03104d8f67?source=topic_page---------475------------------1',
#  '/p/903f942bf52c?source=topic_page---------476------------------1',
#  '/p/230f70425e12?source=topic_page---------477------------------1',
#  '/p/5a92abafb80c?source=topic_page---------478------------------1',
#  '/p/72819896215d?source=topic_page---------479------------------1',
#  '/p/ed7431da11aa?source=topic_page---------480------------------1',
#  '/p/1bfea4cd127?source=topic_page---------481------------------1',
#  '/p/20359c1906d3?source=topic_page---------482------------------1',
#  '/p/bb4c9e74457e?source=topic_page---------483------------------1',
#  '/p/e62cb6dd7fa3?source=topic_page---------484------------------1',
#  '/p/e7f8ee6ab4c2?source=topic_page---------485------------------1',
#  '/p/9ef6cddd0cc1?source=topic_page---------486------------------1',
#  '/p/82800bbe6684?source=topic_page---------487------------------1',
#  '/p/e6f7d1d42e24?source=topic_page---------488------------------1',
#  '/p/7ef89374529d?source=topic_page---------489------------------1',
#  '/p/860d676a1973?source=topic_page---------490------------------1',
#  '/p/b42a9b05c366?source=topic_page---------491------------------1',
#  '/p/eec575f46693?source=topic_page---------492------------------1',
#  '/p/67c45d14e0c4?source=topic_page---------493------------------1',
#  '/p/3f0e31505ca9?source=topic_page---------494------------------1',
#  '/p/1fecd4f5f815?source=topic_page---------495------------------1',
#  '/p/b5cb0f637e44?source=topic_page---------496------------------1',
#  '/p/310935cda86c?source=topic_page---------497------------------1',
#  '/p/debf3fd215c6?source=topic_page---------498------------------1',
#  '/p/1476620be51e?source=topic_page---------499------------------1',
#  '/p/66ffd089e8aa?source=topic_page---------500------------------1',
#  '/p/4a99d14428ba?source=topic_page---------501------------------1',
#  '/p/c08134e7f310?source=topic_page---------502------------------1',
#  '/p/faccad62ad8a?source=topic_page---------503------------------1',
#  '/p/9e1525c37cc3?source=topic_page---------504------------------1',
#  '/p/4ba7ec152728?source=topic_page---------505------------------1',
#  '/p/50f1cdb1e014?source=topic_page---------506------------------1',
#  '/p/1cd5f60bc708?source=topic_page---------507------------------1',
#  '/p/c55d9f79449?source=topic_page---------508------------------1',
#  '/p/d60921775247?source=topic_page---------509------------------1',
#  '/p/aad88e8b8b87?source=topic_page---------510------------------1',
#  '/p/b91ea06ddf63?source=topic_page---------511------------------1',
#  '/p/ac81c4350ce7?source=topic_page---------512------------------1',
#  '/p/8cb12b5de57a?source=topic_page---------513------------------1',
#  '/p/8a36bae307c9?source=topic_page---------514------------------1',
#  '/p/fbff41c4d5db?source=topic_page---------515------------------1',
#  '/p/5203a7244a08?source=topic_page---------516------------------1',
#  '/p/c59a49f97fc5?source=topic_page---------517------------------1',
#  '/p/2a031a0dc9cf?source=topic_page---------518------------------1',
#  '/p/b4a38b032802?source=topic_page---------519------------------1',
#  '/p/8651001e3ff8?source=topic_page---------520------------------1',
#  '/p/9ded0e53c184?source=topic_page---------521------------------1',
#  '/p/a9b4e357ddd9?source=topic_page---------522------------------1',
#  '/p/c8ebbf971012?source=topic_page---------523------------------1',
#  '/p/14a51bd20d1e?source=topic_page---------524------------------1',
#  '/p/eae443b10a98?source=topic_page---------525------------------1',
#  '/p/b26d107bf2c3?source=topic_page---------526------------------1',
#  '/p/f5c399d916ef?source=topic_page---------527------------------1',
#  '/p/e8408d2519f?source=topic_page---------528------------------1',
#  '/p/e02edd7de30?source=topic_page---------529------------------1',
#  '/p/85260bdb992f?source=topic_page---------530------------------1',
#  '/p/65d1e31352aa?source=topic_page---------531------------------1',
#  '/p/5471f1935ff3?source=topic_page---------532------------------1',
#  '/p/9d621567fdc9?source=topic_page---------533------------------1',
#  '/p/c04cc4779d94?source=topic_page---------534------------------1',
#  '/p/c0e0cd318032?source=topic_page---------535------------------1',
#  '/p/ace7121a725b?source=topic_page---------536------------------1',
#  '/p/69b4ef4f5079?source=topic_page---------537------------------1',
#  '/p/cd30c798d523?source=topic_page---------538------------------1',
#  '/p/a9bea9ebc148?source=topic_page---------539------------------1',
#  '/p/522b5c2bd6d0?source=topic_page---------540------------------1',
#  '/p/94fce2d1c39?source=topic_page---------541------------------1',
#  '/p/9700f5672b05?source=topic_page---------542------------------1',
#  '/p/3ae36e2cad3a?source=topic_page---------543------------------1',
#  '/p/81eb57f1e5a9?source=topic_page---------544------------------1',
#  '/p/f33f675e9ab8?source=topic_page---------545------------------1',
#  '/p/932016549375?source=topic_page---------546------------------1',
#  '/p/e7a11b680eb7?source=topic_page---------547------------------1',
#  '/p/c255f4a007fd?source=topic_page---------548------------------1',
#  '/p/e3a3dcbd228d?source=topic_page---------549------------------1',
#  '/p/ee18b8077148?source=topic_page---------550------------------1',
#  '/p/9aa3b6b3de04?source=topic_page---------551------------------1',
#  '/p/29829f92213c?source=topic_page---------552------------------1',
#  '/p/16acb884a0a0?source=topic_page---------553------------------1',
#  '/p/cc64c4024eeb?source=topic_page---------554------------------1',
#  '/p/37b2b7f1384?source=topic_page---------555------------------1',
#  '/p/dfbd2c295c5d?source=topic_page---------556------------------1',
#  '/p/c2a925db6270?source=topic_page---------557------------------1',
#  '/p/137ffa7ea2bc?source=topic_page---------558------------------1',
#  '/p/850b5225a0f0?source=topic_page---------559------------------1',
#  '/p/b51ee7a29fd2?source=topic_page---------560------------------1',
#  '/p/94314c8d95a2?source=topic_page---------561------------------1',
#  '/p/2d19b30d906c?source=topic_page---------562------------------1',
#  '/p/d0e5493132c6?source=topic_page---------563------------------1',
#  '/p/3726bd1ddc1c?source=topic_page---------564------------------1',
#  '/p/48b6f5ce186d?source=topic_page---------565------------------1',
#  '/p/f97999ca93cd?source=topic_page---------566------------------1',
#  '/p/5ab230d2c738?source=topic_page---------567------------------1',
#  '/p/e04245c17c56?source=topic_page---------568------------------1',
#  '/p/933c606f99b0?source=topic_page---------569------------------1',
#  '/p/988fca6b0fca?source=topic_page---------570------------------1',
#  '/p/c2127b00eb03?source=topic_page---------571------------------1',
#  '/p/8e5ccfef2724?source=topic_page---------572------------------1',
#  '/p/7731f6bf7489?source=topic_page---------573------------------1',
#  '/p/7c09dacc1f48?source=topic_page---------574------------------1',
#  '/p/320a7be230c9?source=topic_page---------575------------------1',
#  '/p/c84bd70a29e8?source=topic_page---------576------------------1',
#  '/p/743f0273bf5a?source=topic_page---------577------------------1',
#  '/p/de02e79f1887?source=topic_page---------578------------------1',
#  '/p/7f7309e4d364?source=topic_page---------579------------------1',
#  '/p/f120f2899677?source=topic_page---------580------------------1',
#  '/p/d7e0a7cf6914?source=topic_page---------581------------------1',
#  '/p/3e1837b40a88?source=topic_page---------582------------------1',
#  '/p/5e71618576ab?source=topic_page---------583------------------1',
#  '/p/dafd0b43838?source=topic_page---------584------------------1',
#  '/p/90eb8e70ce59?source=topic_page---------585------------------1',
#  '/p/6d8d7f4d9a6d?source=topic_page---------586------------------1',
#  '/p/2bfe4dff3c7?source=topic_page---------587------------------1',
#  '/p/9d5517caff49?source=topic_page---------588------------------1',
#  '/p/dfeeddb9338d?source=topic_page---------589------------------1',
#  '/p/d3c8a3ecaca7?source=topic_page---------590------------------1',
#  '/p/16bb9193a58?source=topic_page---------591------------------1',
#  '/p/39225c6e4935?source=topic_page---------592------------------1',
#  '/p/e0ce8d0d2bfb?source=topic_page---------593------------------1',
#  '/p/6add97be2051?source=topic_page---------594------------------1',
#  '/p/1e948a12f04e?source=topic_page---------595------------------1',
#  '/p/36fc9df0cfe7?source=topic_page---------596------------------1',
#  '/p/2940c5da3248?source=topic_page---------597------------------1',
#  '/p/fb61fdca7d8c?source=topic_page---------598------------------1',
#  '/p/de3aa0b57029?source=topic_page---------599------------------1',
#  '/p/9b162377ab77?source=topic_page---------600------------------1',
#  '/p/518db9a68a78?source=topic_page---------601------------------1',
#  '/p/b6a4187dbab4?source=topic_page---------602------------------1',
#  '/p/3d63213c8370?source=topic_page---------603------------------1',
#  '/p/132336d8093f?source=topic_page---------604------------------1',
#  '/p/6b634ef174a1?source=topic_page---------605------------------1',
#  '/p/79628016125f?source=topic_page---------606------------------1',
#  '/p/331ec72f1f67?source=topic_page---------607------------------1',
#  '/p/9d5bb7c1cf8f?source=topic_page---------608------------------1',
#  '/p/ae36e97449f5?source=topic_page---------609------------------1',
#  '/p/b91e028fa91d?source=topic_page---------610------------------1',
#  '/p/1e44751116bb?source=topic_page---------611------------------1',
#  '/p/df957595bfc2?source=topic_page---------612------------------1',
#  '/p/4c5c326ee1a6?source=topic_page---------613------------------1',
#  '/p/e58db99137a4?source=topic_page---------614------------------1',
#  '/p/2d9f02f232fa?source=topic_page---------615------------------1',
#  '/p/7f5fdc520d28?source=topic_page---------616------------------1',
#  '/p/7984641e6cdb?source=topic_page---------617------------------1',
#  '/p/a19b36867a33?source=topic_page---------618------------------1',
#  '/p/2128b76f042a?source=topic_page---------619------------------1',
#  '/p/4e66fc7b6d27?source=topic_page---------620------------------1',
#  '/p/26ddbe49de70?source=topic_page---------621------------------1',
#  '/p/b564cf8f798e?source=topic_page---------622------------------1',
#  '/p/9de299abdf13?source=topic_page---------623------------------1',
#  '/p/4bbfa80359?source=topic_page---------624------------------1',
#  '/p/6f38d3d6c995?source=topic_page---------625------------------1',
#  '/p/4a84f7de011f?source=topic_page---------626------------------1',
#  '/p/94a1f20aa1b4?source=topic_page---------627------------------1',
#  '/p/52a355da8e7b?source=topic_page---------628------------------1',
#  '/p/c69f84902983?source=topic_page---------629------------------1',
#  '/p/9a53fbf80487?source=topic_page---------630------------------1',
#  '/p/ae825271811f?source=topic_page---------631------------------1',
#  '/p/60bd26f31676?source=topic_page---------632------------------1',
#  '/p/e7f517b30715?source=topic_page---------633------------------1',
#  '/p/3d851d7f0b26?source=topic_page---------634------------------1',
#  '/p/646bc39af26?source=topic_page---------635------------------1',
#  '/p/bb91ce18ab56?source=topic_page---------636------------------1',
#  '/p/9b759ca21cda?source=topic_page---------637------------------1',
#  '/p/5edcd3777a46?source=topic_page---------638------------------1',
#  '/p/226d4aba17f6?source=topic_page---------639------------------1',
#  '/p/cc152cf4f51b?source=topic_page---------640------------------1',
#  '/p/2520ef9d3dbc?source=topic_page---------641------------------1',
#  '/p/dcfd0179cf80?source=topic_page---------642------------------1',
#  '/p/73eeea488b8b?source=topic_page---------643------------------1',
#  '/p/825966908393?source=topic_page---------644------------------1',
#  '/p/f4e264c320fd?source=topic_page---------645------------------1',
#  '/p/8eb15cc2ee1f?source=topic_page---------646------------------1',
#  '/p/2d0442472a15?source=topic_page---------647------------------1',
#  '/p/d869212b1f62?source=topic_page---------648------------------1',
#  '/p/1de862421981?source=topic_page---------649------------------1',
#  '/p/94bf4e423017?source=topic_page---------650------------------1',
#  '/p/f1fe2f3c53b5?source=topic_page---------651------------------1',
#  '/p/4bc9b0453ee5?source=topic_page---------652------------------1',
#  '/p/eff64a1b26af?source=topic_page---------653------------------1',
#  '/p/848723888fa0?source=topic_page---------654------------------1',
#  '/p/21d251058af3?source=topic_page---------655------------------1',
#  '/p/1fc859cb29a?source=topic_page---------656------------------1',
#  '/p/e5bef93df2f5?source=topic_page---------657------------------1',
#  '/p/9a38ff7be821?source=topic_page---------658------------------1',
#  '/p/9e866df5d269?source=topic_page---------659------------------1',
#  '/p/aff650e80316?source=topic_page---------660------------------1',
#  '/p/5fc49dd6fa61?source=topic_page---------661------------------1',
#  '/p/613630e7c1f?source=topic_page---------662------------------1',
#  '/p/35cafce00ed2?source=topic_page---------663------------------1',
#  '/p/b381e60d32f9?source=topic_page---------664------------------1',
#  '/p/4611d8e363b9?source=topic_page---------665------------------1',
#  '/p/38ed2e5a643d?source=topic_page---------666------------------1',
#  '/p/31d0fa6d7b61?source=topic_page---------667------------------1',
#  '/p/494e8778d0ed?source=topic_page---------668------------------1',
#  '/p/f7192d1b8506?source=topic_page---------669------------------1',
#  '/p/88718e08124f?source=topic_page---------670------------------1',
#  '/p/a0f694b17053?source=topic_page---------671------------------1',
#  '/p/7a1c0371f2fa?source=topic_page---------672------------------1',
#  '/p/9be84343c713?source=topic_page---------673------------------1',
#  '/p/e3a4b2384a40?source=topic_page---------674------------------1',
#  '/p/cb02cfa3fc5e?source=topic_page---------675------------------1',
#  '/p/6a6a57eb83ac?source=topic_page---------676------------------1',
#  '/p/d1f77f555d40?source=topic_page---------677------------------1',
#  '/p/55faf92799bf?source=topic_page---------678------------------1',
#  '/p/b9729670ec6d?source=topic_page---------679------------------1',
#  '/p/99baf11cc219?source=topic_page---------680------------------1',
#  '/p/8ce57ab41f66?source=topic_page---------681------------------1',
#  '/p/5fac7c06bcba?source=topic_page---------682------------------1',
#  '/p/f0aad48345eb?source=topic_page---------683------------------1',
#  '/p/739fd000cd9d?source=topic_page---------684------------------1',
#  '/p/a369ad7948b2?source=topic_page---------685------------------1',
#  '/p/faf1cdaf88fe?source=topic_page---------686------------------1',
#  '/p/3af27e312d01?source=topic_page---------687------------------1',
# ...
#  '/p/5d690ef0fc10?source=topic_page---------759------------------1',
#  '/p/fa8b9af0e93e?source=topic_page---------760------------------1',
#  '/p/9670793e3431?source=topic_page---------761------------------1',
#  '/p/48164b79bcd?source=topic_page---------762------------------1',
#  '/p/6a73b233622?source=topic_page---------763------------------1',
#  '/p/22fc4bedc2ac?source=topic_page---------764------------------1',
#  '/p/1da8855fecb0?source=topic_page---------765------------------1',
#  '/p/b4bf3453f6b5?source=topic_page---------766------------------1',
#  '/p/cd7eadad010d?source=topic_page---------767------------------1',
#  '/p/68f23824dbe?source=topic_page---------768------------------1',
#  '/p/10e1f0b5363d?source=topic_page---------769------------------1',
#  '/p/af60926e6fb3?source=topic_page---------770------------------1',
#  '/p/7cf1e809ba6e?source=topic_page---------771------------------1',
#  '/p/3aa27f55485?source=topic_page---------772------------------1',
#  '/p/9de0da74fdad?source=topic_page---------773------------------1',
#  '/p/9380172366ea?source=topic_page---------774------------------1',
#  '/p/67d1c45e9483?source=topic_page---------775------------------1',
#  '/p/73d4793b4dc6?source=topic_page---------776------------------1',
#  '/p/e121dd1d55e?source=topic_page---------777------------------1',
#  '/p/e34649174166?source=topic_page---------778------------------1',
#  '/p/d6b604e276c?source=topic_page---------779------------------1',
#  '/p/a1e0216c8a23?source=topic_page---------780------------------1',
#  '/p/191816492747?source=topic_page---------781------------------1',
#  '/p/eec6cb63e898?source=topic_page---------782------------------1',
#  '/p/8a2f35c8e5cf?source=topic_page---------783------------------1',
#  '/p/30b09f801089?source=topic_page---------784------------------1',
#  '/p/4083a2bac1e5?source=topic_page---------785------------------1',
#  '/p/4a4607a870b0?source=topic_page---------786------------------1',
#  '/p/28ae4f3b5616?source=topic_page---------787------------------1',
#  '/p/a08c31f83249?source=topic_page---------788------------------1',
#  '/p/f95b16fefc60?source=topic_page---------789------------------1',
#  '/p/ae07511a2039?source=topic_page---------790------------------1',
#  '/p/b89b9c3567c1?source=topic_page---------791------------------1',
#  '/p/bf28f614bfa7?source=topic_page---------792------------------1',
#  '/p/84898e5341a?source=topic_page---------793------------------1',
#  '/p/aed86f968810?source=topic_page---------794------------------1',
#  '/p/e6c377a78be3?source=topic_page---------795------------------1',
#  '/p/a7bd3ab38ed9?source=topic_page---------796------------------1',
#  '/p/60416ea4c5c?source=topic_page---------797------------------1',
#  '/p/f4be59621eaa?source=topic_page---------798------------------1',
#  '/p/f61d3527214d?source=topic_page---------799------------------1',
#  '/p/351da67efab4?source=topic_page---------800------------------1',
#  '/p/7107e8c112fa?source=topic_page---------801------------------1',
#  '/p/7d75839a20ea?source=topic_page---------802------------------1',
#  '/p/df9b63f575f7?source=topic_page---------803------------------1',
#  '/p/fb5644d686df?source=topic_page---------804------------------1',
#  '/p/4f7a60c92ad8?source=topic_page---------805------------------1',
#  '/p/4003d7bbed32?source=topic_page---------806------------------1',
#  '/p/538004a37f9b?source=topic_page---------807------------------1',
#  '/p/45df4566edce?source=topic_page---------808------------------1',
#  '/p/b9579b3a878b?source=topic_page---------809------------------1',
#  '/p/9961d4bcf048?source=topic_page---------810------------------1',
#  '/p/64423fc0d57e?source=topic_page---------811------------------1',
#  '/p/faaf4cc2d830?source=topic_page---------812------------------1',
#  '/p/6e6a56cdd535?source=topic_page---------813------------------1',
#  '/p/24e5e0b5d7a0?source=topic_page---------814------------------1',
#  '/p/76c7160b04f9?source=topic_page---------815------------------1',
#  '/p/4bb2b1225083?source=topic_page---------816------------------1',
#  '/p/4abfe5a30ba?source=topic_page---------817------------------1',
#  '/p/ffcfe6868b02?source=topic_page---------818------------------1',
#  '/p/eea0907cd0ae?source=topic_page---------819------------------1',
#  '/p/23782be391d1?source=topic_page---------820------------------1',
#  '/p/8f1072f730e9?source=topic_page---------821------------------1',
#  '/p/5721d139a171?source=topic_page---------822------------------1',
#  '/p/5389921ab60b?source=topic_page---------823------------------1',
#  '/p/b87eda5715f5?source=topic_page---------824------------------1',
#  '/p/b3c77921d9fd?source=topic_page---------825------------------1',
#  '/p/77a2f30b8cef?source=topic_page---------826------------------1',
#  '/p/cd6c630322e9?source=topic_page---------827------------------1',
#  '/p/d58906e22275?source=topic_page---------828------------------1',
#  '/p/f4a35aacc951?source=topic_page---------829------------------1',
#  '/p/6c2872c28473?source=topic_page---------830------------------1',
#  '/p/7c1f5c4bf4b3?source=topic_page---------831------------------1',
#  '/p/b344c2087448?source=topic_page---------832------------------1',
#  '/p/c04ca734c6bb?source=topic_page---------833------------------1',
#  '/p/4ebd91cd31a3?source=topic_page---------834------------------1',
#  '/p/1b03190048fd?source=topic_page---------835------------------1',
#  '/p/1c4d3e6cfa55?source=topic_page---------836------------------1',
#  '/p/958c35957574?source=topic_page---------837------------------1',
#  '/p/c56c14a7afc3?source=topic_page---------838------------------1',
#  '/p/653a4b8b2720?source=topic_page---------839------------------1',
#  '/p/3f9f5d54187b?source=topic_page---------840------------------1',
#  '/p/f5e9864047e1?source=topic_page---------841------------------1',
#  '/p/c19954da0454?source=topic_page---------842------------------1',
#  '/p/63b204727591?source=topic_page---------843------------------1',
#  '/p/689d0c12fe39?source=topic_page---------844------------------1',
#  '/p/4338746dacec?source=topic_page---------845------------------1',
#  '/p/d81fd32932e1?source=topic_page---------846------------------1',
#  '/p/a45d2785e193?source=topic_page---------847------------------1',
#  '/p/3211861ce7a3?source=topic_page---------848------------------1',
#  '/p/ea8d17e12f22?source=topic_page---------849------------------1',
#  '/p/f0f029c26f30?source=topic_page---------850------------------1',
#  '/p/476579837499?source=topic_page---------851------------------1',
#  '/p/95ee650d9dc?source=topic_page---------852------------------1',
#  '/p/7e95e2c7f3e7?source=topic_page---------853------------------1',
#  '/p/4d04a501e2c7?source=topic_page---------854------------------1',
#  '/p/336e8ccf7dd0?source=topic_page---------855------------------1',
#  '/p/8cbd34cb7262?source=topic_page---------856------------------1',
#  '/p/a5d47b78679e?source=topic_page---------857------------------1',
#  '/p/d142229832d6?source=topic_page---------858------------------1',
#  '/p/c2d84448e69c?source=topic_page---------859------------------1',
#  '/p/fb8ed95273c6?source=topic_page---------860------------------1',
#  '/p/15c7f8001794?source=topic_page---------861------------------1',
#  '/p/859ce76a3eee?source=topic_page---------862------------------1',
#  '/p/9603a2ebea40?source=topic_page---------863------------------1',
#  '/p/2af6f8fc0fcd?source=topic_page---------864------------------1',
#  '/p/1fbd7e6b145a?source=topic_page---------865------------------1',
#  '/p/7a5d83d03069?source=topic_page---------866------------------1',
#  '/p/6f4247335455?source=topic_page---------867------------------1',
#  '/p/6ce14c84e21b?source=topic_page---------868------------------1',
#  '/p/fca9f857a567?source=topic_page---------869------------------1',
#  '/p/2902d074f5ba?source=topic_page---------870------------------1',
#  '/p/ed72d06418f1?source=topic_page---------871------------------1',
#  '/p/5a86701e9a27?source=topic_page---------872------------------1',
#  '/p/a76a86fce05c?source=topic_page---------873------------------1',
#  '/p/b40bb0ddefe1?source=topic_page---------874------------------1',
#  '/p/e121ba4ed3b1?source=topic_page---------875------------------1',
#  '/p/cb34b05fc84e?source=topic_page---------876------------------1',
#  '/p/adfc892e64e3?source=topic_page---------877------------------1',
#  '/p/39e44150e1d4?source=topic_page---------878------------------1',
#  '/p/f262c7735847?source=topic_page---------879------------------1',
#  '/p/44195d37105f?source=topic_page---------880------------------1',
#  '/p/4e55f8dadcc2?source=topic_page---------881------------------1',
#  '/p/e4bff0d6cf20?source=topic_page---------882------------------1',
#  '/p/15fce7d10437?source=topic_page---------883------------------1',
#  '/p/7255d632598c?source=topic_page---------884------------------1',
#  '/p/99c49ef15772?source=topic_page---------885------------------1',
#  '/p/d3d058e4e472?source=topic_page---------886------------------1',
#  '/p/c472b821e4bf?source=topic_page---------887------------------1',
#  '/p/1a6cb41fc92a?source=topic_page---------888------------------1',
#  '/p/4b2959c03a35?source=topic_page---------889------------------1',
#  '/p/2f368ee36599?source=topic_page---------890------------------1',
#  '/p/91fae189d778?source=topic_page---------891------------------1',
#  '/p/e5f35e423b1b?source=topic_page---------892------------------1',
#  '/p/bffc4152e978?source=topic_page---------893------------------1',
#  '/p/5116867d5041?source=topic_page---------894------------------1',
#  '/p/917df260469?source=topic_page---------895------------------1',
#  '/p/d4110e73ebea?source=topic_page---------896------------------1',
#  '/p/be0472f2599c?source=topic_page---------897------------------1',
#  '/p/577a3fb2f17?source=topic_page---------898------------------1',
#  '/p/b094ddd07d4?source=topic_page---------899------------------1',
#  '/p/49b88beb0ad1?source=topic_page---------900------------------1',
#  '/p/e22546deb454?source=topic_page---------901------------------1',
#  '/p/cb0b2737128?source=topic_page---------902------------------1',
#  '/p/7cb3f56daf9b?source=topic_page---------903------------------1',
#  '/p/c0a92ed1f76f?source=topic_page---------904------------------1',
#  '/p/1c298570d191?source=topic_page---------905------------------1',
#  '/p/f3c347322315?source=topic_page---------906------------------1',
#  '/p/c553c45ab072?source=topic_page---------907------------------1',
#  '/p/8666b31e2d37?source=topic_page---------908------------------1',
#  '/p/f71e9ba90566?source=topic_page---------909------------------1',
#  '/p/9b4e6dbced76?source=topic_page---------910------------------1',
#  '/p/b5bd66472c12?source=topic_page---------911------------------1',
#  '/p/e374434a448c?source=topic_page---------912------------------1',
#  '/p/a4fcf62e6e2f?source=topic_page---------913------------------1',
#  '/p/53442ca0805a?source=topic_page---------914------------------1',
#  '/p/f2e40c40cd75?source=topic_page---------915------------------1',
#  '/p/fa58dddc7f0d?source=topic_page---------916------------------1',
#  '/p/765ba23c5ab9?source=topic_page---------917------------------1',
#  '/p/183a72e89c0d?source=topic_page---------918------------------1',
#  '/p/1f05e3934cb6?source=topic_page---------919------------------1',
#  '/p/14e6029c8024?source=topic_page---------920------------------1',
#  '/p/9e6c787a32ac?source=topic_page---------921------------------1',
#  '/p/7b3beaa4680?source=topic_page---------922------------------1',
#  '/p/be509ca21b65?source=topic_page---------923------------------1',
#  '/p/e46329764d28?source=topic_page---------924------------------1',
#  '/p/c4208efb6367?source=topic_page---------925------------------1',
#  '/p/612bb473ac1d?source=topic_page---------926------------------1',
#  '/p/be3f77700f14?source=topic_page---------927------------------1',
#  '/p/f98b24d645a0?source=topic_page---------928------------------1',
#  '/p/4ce5f25e7046?source=topic_page---------929------------------1',
#  '/p/c2a28a08dd95?source=topic_page---------930------------------1',
#  '/p/7fcd131a341c?source=topic_page---------931------------------1',
#  '/p/49c1d536d714?source=topic_page---------932------------------1',
#  '/p/9b9a268c651a?source=topic_page---------933------------------1',
#  '/p/38f86df6f768?source=topic_page---------934------------------1',
#  '/p/896afc3a34c4?source=topic_page---------935------------------1',
#  '/p/2c06ec398098?source=topic_page---------936------------------1',
#  '/p/5e1d5812e1e7?source=topic_page---------937------------------1',
#  '/p/c9faf63bcf6b?source=topic_page---------938------------------1',
#  '/p/fbb81468fb27?source=topic_page---------939------------------1',
#  '/p/295d89f2a9a0?source=topic_page---------940------------------1',
#  '/p/8c9174871016?source=topic_page---------941------------------1',
#  '/p/7f3501d53f63?source=topic_page---------942------------------1',
#  '/p/5eaa0d6ad057?source=topic_page---------943------------------1',
#  '/p/bddd4caa7b51?source=topic_page---------944------------------1',
#  '/p/33597d6c44d1?source=topic_page---------945------------------1',
#  '/p/8527026fc667?source=topic_page---------946------------------1',
#  '/p/41f2812b8704?source=topic_page---------947------------------1',
#  '/p/1187a8367d74?source=topic_page---------948------------------1',
#  '/p/d14167cd157a?source=topic_page---------949------------------1',
#  '/p/bb02df378ba?source=topic_page---------950------------------1',
#  '/p/2d145589d814?source=topic_page---------951------------------1',
#  '/p/dd38c39929df?source=topic_page---------952------------------1',
#  '/p/feb6ae656b95?source=topic_page---------953------------------1',
#  '/p/629b4f9343cc?source=topic_page---------954------------------1',
#  '/p/bcdaf8fbe960?source=topic_page---------955------------------1',
#  '/p/6e013a3291a3?source=topic_page---------956------------------1',
#  '/p/566448c6e3ee?source=topic_page---------957------------------1',
#  '/p/6694e2f7d01c?source=topic_page---------958------------------1',
#  '/p/6b4d717b8ead?source=topic_page---------959------------------1',
#  '/p/7ce91164421c?source=topic_page---------960------------------1',
#  '/p/914810ab7300?source=topic_page---------961------------------1',
#  '/p/5c310e1ef3f9?source=topic_page---------962------------------1',
#  '/p/fa0fb8a69aba?source=topic_page---------963------------------1',
#  '/p/1bffedaa6cf5?source=topic_page---------964------------------1',
#  '/p/6ac2d6a744c5?source=topic_page---------965------------------1',
#  '/p/3b9a67ff36a5?source=topic_page---------966------------------1',
#  '/p/e449d3109d71?source=topic_page---------967------------------1',
#  '/p/b43e80edcf60?source=topic_page---------968------------------1',
#  '/p/b568607ab216?source=topic_page---------969------------------1',
#  '/p/daa4124746be?source=topic_page---------970------------------1',
#  '/p/bc623a3b4625?source=topic_page---------971------------------1',
#  '/p/21a2c3208d3e?source=topic_page---------972------------------1',
#  '/p/f1cb8367fc21?source=topic_page---------973------------------1',
#  '/p/cba708805d4e?source=topic_page---------974------------------1',
#  '/p/d1d8bf1de7d2?source=topic_page---------975------------------1',
#  '/p/c9700a7cf36d?source=topic_page---------976------------------1',
#  '/p/42e2d2ac86d?source=topic_page---------977------------------1',
#  '/p/8cdb766edcbe?source=topic_page---------978------------------1',
#  '/p/8c27a07250b8?source=topic_page---------979------------------1',
#  '/p/f21c9642d49c?source=topic_page---------980------------------1',
#  '/p/8baa33e1d9ac?source=topic_page---------981------------------1',
#  '/p/9ea8ce0e298a?source=topic_page---------982------------------1',
#  '/p/598a11eb2c56?source=topic_page---------983------------------1',
#  '/p/35d7c8aec846?source=topic_page---------984------------------1',
#  '/p/948302f95b5c?source=topic_page---------985------------------1',
#  '/p/cc5c1b32a7f?source=topic_page---------986------------------1',
#  '/p/6b8499f89b?source=topic_page---------987------------------1',
#  '/p/bb02416bb0ad?source=topic_page---------988------------------1',
#  '/p/35d991f9f839?source=topic_page---------989------------------1',
#  '/p/e390a3b19d78?source=topic_page---------990------------------1',
#  ...]

# %%
text1= pd.DataFrame(text)
#category1= pd.DataFrame(category)
link= pd.DataFrame(res2)
frames = [link, text1]
result = pd.concat(frames, axis=1)
result.columns = ['Link1', 'Title']

# %%
result
# Out:
#                                                   Link1  \
# 0     /p/a3832f587bee?source=topic_page---------0---...
# 1     /p/af4499558ce0?source=topic_page---------1---...
# 2     /p/b64c40484774?source=topic_page---------2---...
# 3     /p/36fbed0268cf?source=topic_page---------3---...
# 4     /p/22c43f236ff5?source=topic_page---------4---...
# 5     /p/7a3088cdff78?source=topic_page---------5---...
# 6     /p/17db67de2532?source=topic_page---------6---...
# 7     /p/9b96528db259?source=topic_page---------7---...
# 8     /p/54add1467545?source=topic_page---------8---...
# 9     /p/ec30ac17172d?source=topic_page---------9---...
# 10    /p/a3832f587bee?source=topic_page---------0---...
# 11    /p/af4499558ce0?source=topic_page---------1---...
# 12    /p/b64c40484774?source=topic_page---------2---...
# 13    /p/36fbed0268cf?source=topic_page---------4---...
# 14    /p/22c43f236ff5?source=topic_page---------5---...
# 15    /p/7a3088cdff78?source=topic_page---------6---...
# 16    /p/3b6b1885b5a1?source=topic_page---------7---...
# 17    /p/17db67de2532?source=topic_page---------8---...
# 18    /p/9b96528db259?source=topic_page---------9---...
# 19    /p/ddf9780d714c?source=topic_page---------10--...
# 20    /p/727c8ece07b7?source=topic_page---------11--...
# 21    /p/2d53766507d2?source=topic_page---------12--...
# 22    /p/54add1467545?source=topic_page---------13--...
# 23    /p/9673546b19af?source=topic_page---------14--...
# 24    /p/ec30ac17172d?source=topic_page---------15--...
# 25    /p/31f7964a96d8?source=topic_page---------16--...
# 26    /p/fa01c1f75d3f?source=topic_page---------17--...
# 27    /p/87f92217d085?source=topic_page---------18--...
# 28    /p/264d483ee0de?source=topic_page---------19--...
# 29    /p/a8659060cab5?source=topic_page---------20--...
# ...                                                 ...
# 1613  /p/60b51d913860?source=topic_page---------1604...
# 1614  /p/aaf05e5e4aad?source=topic_page---------1605...
# 1615  /p/6e16271c0ce?source=topic_page---------1606-...
# 1616  /p/93628670efe?source=topic_page---------1607-...
# 1617  /p/65d111ecdc11?source=topic_page---------1608...
# 1618  /p/3abdf99068ee?source=topic_page---------1609...
# 1619  /p/a1347f32fd8f?source=topic_page---------1610...
# 1620  /p/bc8ae69ea305?source=topic_page---------1611...
# 1621  /p/b82b082d5f3d?source=topic_page---------1612...
# 1622  /p/5bf98104cea2?source=topic_page---------1613...
# 1623  /p/668695445f76?source=topic_page---------1614...
# 1624  /p/181903cfe0a?source=topic_page---------1615-...
# 1625  /p/4760f363c1dc?source=topic_page---------1616...
# 1626  /p/bebe10cb2f02?source=topic_page---------1617...
# 1627  /p/9498737f5b6c?source=topic_page---------1618...
# 1628  /p/9840cdc8857b?source=topic_page---------1619...
# 1629  /p/f63e9df1363a?source=topic_page---------1620...
# 1630  /p/60e2149cffa3?source=topic_page---------1621...
# 1631  /p/7ac2e5f84300?source=topic_page---------1622...
# 1632  /p/d6ff62747a21?source=topic_page---------1623...
# 1633  /p/e067410aaf1b?source=topic_page---------1624...
# 1634  /p/518a292cf58c?source=topic_page---------1625...
# 1635  /p/352177059149?source=topic_page---------1626...
# 1636  /p/ea69fc1ce38c?source=topic_page---------1627...
# 1637  /p/5b2c4bd58fda?source=topic_page---------1628...
# 1638  /p/7b551473a171?source=topic_page---------1629...
# 1639  /p/ea0bf2a29696?source=topic_page---------1630...
# 1640  /p/4bb6d0b8fb84?source=topic_page---------1631...
# 1641  /p/cce0fe222a71?source=topic_page---------1632...
# 1642  /p/3469fc2e9b22?source=topic_page---------1633...
#
#                                                   Title
# 0                                      The 50/50 Murder
# 1                             The End of Snap and Tesla
# 2     Why I Left My Big Fancy Tech Job and Wrote a Book
# 3                                    The Big Disruption
# 4                         Facebook Is Just Like the NSA
# 5                         Learning to Drink My Feelings
# 6     Brett Kavanaugh Is A Liar (And 44 Other Things...
# 7     How to Create Any Habit With Advice From the F...
# 8     You Don’t Need a Breakthrough, You Need a Micr...
# 9           What My Parents Never Taught Me About Money
# 10                                     The 50/50 Murder
# 11                            The End of Snap and Tesla
# 12    Why I Left My Big Fancy Tech Job and Wrote a Book
# 13                                   The Big Disruption
# 14                        Facebook Is Just Like the NSA
# 15                        Learning to Drink My Feelings
# 16    Internet Dudes Discover Sideways Cunnilingus (...
# 17    Brett Kavanaugh Is A Liar (And 44 Other Things...
# 18    How to Create Any Habit With Advice From the F...
# 19               iPhone XS: Why It’s A Whole New Camera
# 20    10 things I wish I knew before my first corpor...
# 21    Growing Our SaaS Company To $1M+ ARR: 7 People...
# 22    You Don’t Need a Breakthrough, You Need a Micr...
# 23                      The Tyranny of the Perfect Life
# 24          What My Parents Never Taught Me About Money
# 25                     Why the Digital Detox Should Die
# 26                    The Riemann Hypothesis, explained
# 27                          One Small Step for the Web…
# 28                   How to Make a Dent in the Universe
# 29                          Jeff Flake Explains Himself
# ...                                                 ...
# 1613  The Original Beauty and the Beast Opening Numb...
# 1614                           The productivity paradox
# 1615  What Silicon Valley, Tinder, And Trump Have In...
# 1616                                   Robin’s-Egg Blue
# 1617  The Red Pom Hat on The Fearless Girl (and the ...
# 1618  Malcolm Gladwell Wants to Make the World Safe ...
# 1619  Information Wars: A Window into the Alternativ...
# 1620  The Financial Aid Loophole That Cost Me Thousands
# 1621                        The crimes against dopamine
# 1622               The Facts are True, the News is Fake
# 1623                            Iteration is not design
# 1624                                      Why Men Drink
# 1625                                Life-Hacking Isabel
# 1626                        How Do I Know If I’m Trans?
# 1627                  A Brief History of Random Numbers
# 1628  Breaking Down the Father on BBC Being Interrup...
# 1629        Pinkwashing: Or, How Not To Market to Women
# 1630                                The Search for Self
# 1631          “You don’t get it. You aren’t the point.”
# 1632  I am Indian American, and it’s 2017. But I sti...
# 1633  The Scary Thing About GMO That Nobody’s Talkin...
# 1634                                          “I’m in.”
# 1635              The Crippling Fear of Medical Poverty
# 1636  The CIA just lost control of its hacking arsen...
# 1637                                  “I Do” Better Now
# 1638                         Decapitating Consciousness
# 1639    A Career Retrospective—10 years working in tech
# 1640  How reader engagement helped unearth  the Shel...
# 1641     A History and Future of the Rise of the Robots
# 1642                            Hype Driven Development
#
# [1643 rows x 2 columns]

# %%
result.to_csv('/Users/admin/Desktop/xxm/links_Popular.csv')
